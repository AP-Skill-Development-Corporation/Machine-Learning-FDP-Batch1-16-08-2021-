# %%
import pandas as pd

l=[10,20,30,40,50]

df=pd.DataFrame(l)
df
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
df=pd.DataFrame([[1,2],[3,4],[5,6],[100,200]])
df
# Out:
#      0    1
# 0    1    2
# 1    3    4
# 2    5    6
# 3  100  200

# %%
df=pd.DataFrame([[1,2],[3,4],[5,6],[100,200]],columns=['one','two'])
df
# Out:
#    one  two
# 0    1    2
# 1    3    4
# 2    5    6
# 3  100  200

# %%
# add a column names
df=pd.DataFrame([[1,2],[3,4],[5,6],[100,200]])
df.columns=["one","two"]
df
# Out:
#    one  two
# 0    1    2
# 1    3    4
# 2    5    6
# 3  100  200

# %%
# add a index names
df=pd.DataFrame([[1,2],[3,4],[5,6],[100,200]],columns=['one','two'])
df.index=['a','b','c','d']
df
# Out:
#    one  two
# a    1    2
# b    3    4
# c    5    6
# d  100  200

# %%
# dictionary to dataframe
d={"sno":[101,102,103,104],'sname':['sai','venkat','rahul','raji']}
df=pd.DataFrame(d)
df
# Out:
#    sno   sname
# 0  101     sai
# 1  102  venkat
# 2  103   rahul
# 3  104    raji

# %%
# add a new column
d={"sno":[101,102,103,104],'sname':['sai','venkat','rahul','raji']}
df=pd.DataFrame(d)
df['sage']=[23,25,22,30]
df
# Out:
#    sno   sname  sage
# 0  101     sai    23
# 1  102  venkat    25
# 2  103   rahul    22
# 3  104    raji    30

# %%
d={"sno":[101,102,103,104],'sname':['sai','venkat','rahul','raji']}
df=pd.DataFrame(d)
df['sage']=[23,25,22,30]
df['sem1']=[50,55,52,30]
df['sem2']=[53,50,25,10]
df
# Out:
#    sno   sname  sage  sem1  sem2
# 0  101     sai    23    50    53
# 1  102  venkat    25    55    50
# 2  103   rahul    22    52    25
# 3  104    raji    30    30    10

# %%
# how to access the data from df

a=df['sage']
a
# Out:
# 0    23
# 1    25
# 2    22
# 3    30
# Name: sage, dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
b=df[['sage']]
b
# Out:
#    sage
# 0    23
# 1    25
# 2    22
# 3    30

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
b=df[['sage','sem2']]
b
# Out:
#    sage  sem2
# 0    23    53
# 1    25    50
# 2    22    25
# 3    30    10

# %%
df['total']=df['sem1']+df['sem2']
df
# Out:
#    sno   sname  sage  sem1  sem2  total
# 0  101     sai    23    50    53    103
# 1  102  venkat    25    55    50    105
# 2  103   rahul    22    52    25     77
# 3  104    raji    30    30    10     40

# %%
df['avg']=df['total']/2
df
# Out:
#    sno   sname  sage  sem1  sem2  total   avg
# 0  101     sai    23    50    53    103  51.5
# 1  102  venkat    25    55    50    105  52.5
# 2  103   rahul    22    52    25     77  38.5
# 3  104    raji    30    30    10     40  20.0

# %%
df.set_index('sno',inplace=True)

# %%
df
# Out:
#       sname  sage  sem1  sem2  total   avg
# sno
# 101     sai    23    50    53    103  51.5
# 102  venkat    25    55    50    105  52.5
# 103   rahul    22    52    25     77  38.5
# 104    raji    30    30    10     40  20.0

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    sno   sname  sage  sem1  sem2  total   avg
# 0  101     sai    23    50    53    103  51.5
# 1  102  venkat    25    55    50    105  52.5
# 2  103   rahul    22    52    25     77  38.5
# 3  104    raji    30    30    10     40  20.0

# %%
# access the data row wise

# loc => location
# iloc => index location

df.loc[1:2]
# Out:
#    sno   sname  sage  sem1  sem2  total   avg
# 1  102  venkat    25    55    50    105  52.5
# 2  103   rahul    22    52    25     77  38.5

# %%
df.loc[1:2,'sno':'sname']   # loc[row,column]
# Out:
#    sno   sname
# 1  102  venkat
# 2  103   rahul

# %%
df.loc[1:1,['sname','total']]
# Out:
#     sname  total
# 1  venkat    105

# %%
df.set_index('sno',inplace=True)

# %%
df
# Out:
#       sname  sage  sem1  sem2  total   avg
# sno
# 101     sai    23    50    53    103  51.5
# 102  venkat    25    55    50    105  52.5
# 103   rahul    22    52    25     77  38.5
# 104    raji    30    30    10     40  20.0

# %%
df.loc[102:104]
# Out:
#       sname  sage  sem1  sem2  total   avg
# sno
# 102  venkat    25    55    50    105  52.5
# 103   rahul    22    52    25     77  38.5
# 104    raji    30    30    10     40  20.0

# %%
df.iloc[1:3]
# Out:
#       sname  sage  sem1  sem2  total   avg
# sno
# 102  venkat    25    55    50    105  52.5
# 103   rahul    22    52    25     77  38.5

# %%
df.iloc[1:3,1:4]
# Out:
#      sage  sem1  sem2
# sno
# 102    25    55    50
# 103    22    52    25

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    sno   sname  sage  sem1  sem2  total   avg
# 0  101     sai    23    50    53    103  51.5
# 1  102  venkat    25    55    50    105  52.5
# 2  103   rahul    22    52    25     77  38.5
# 3  104    raji    30    30    10     40  20.0

# %%
df.loc[1:1]
# Out:
#    sno   sname  sage  sem1  sem2  total   avg
# 1  102  venkat    25    55    50    105  52.5

# %%
df[['sname','total']]
# Out:
#     sname  total
# 0     sai    103
# 1  venkat    105
# 2   rahul     77
# 3    raji     40

# %%
df['sname']=='venkat'
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# Name: sname, dtype: bool

# %%
s=df[df['sname']=='venkat']
s[['sname','total']]
# Out:
#     sname  total
# 1  venkat    105

# %%
df.iloc[1,3]
# Out:
# 55

# %%
# access the data using filters
df
# Out:
#    sno   sname  sage  sem1  sem2  total   avg
# 0  101     sai    23    50    53    103  51.5
# 1  102  venkat    25    55    50    105  52.5
# 2  103   rahul    22    52    25     77  38.5
# 3  104    raji    30    30    10     40  20.0

# %%
df['total']>=80
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: total, dtype: bool

# %%
df[df['total']>=80]
# Out:
#    sno   sname  sage  sem1  sem2  total   avg
# 0  101     sai    23    50    53    103  51.5
# 1  102  venkat    25    55    50    105  52.5

# %%
# age is above 20 and total marks above 80

df[(df['sage']>20)&(df['total']>80)]
# Out:
#    sno   sname  sage  sem1  sem2  total   avg
# 0  101     sai    23    50    53    103  51.5
# 1  102  venkat    25    55    50    105  52.5

# %%
d={'sno':34,'sname':'b','sage':33,'sem1':44,'sem2':44,'total':45,'avg':44}
df=df.append(d,ignore_index=True)
df
# Out:
#    sno   sname  sage  sem1  sem2  total   avg  sem3
# 0  101     sai    23    50  53.0    103  51.5   NaN
# 1  102  venkat    25    55  50.0    105  52.5   NaN
# 2  103   rahul    22    52  25.0     77  38.5   NaN
# 3  104    raji    30    30  10.0     40  20.0   NaN
# 4   34       b    33    44   NaN     45  44.0  44.0
# 5   34       b    33    44   NaN     45  44.0  44.0
# 6   34       b    33    44  44.0     45  44.0   NaN

# %% [markdown]
# ### how to access the data from files
#
# 1. excel  => pd.read_excel("fn")
# 2. csv
# 3. json
# 4. html
